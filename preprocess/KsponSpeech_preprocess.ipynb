# %% [markdown]
# ## 1. Install Packages

# %%
# !pip install pandas
# !pip install sentencepiece
# !pip install hgtk
# !pip install gluonnlp

# !git clone https://github.com/SKTBrain/KoBERT.git
# !pip install -r KoBERT/requirements.txt
# !pip install KoBERT/.

# %% [markdown]
# ## 2. Data-Preprocess

# %%
# BASE_PATH = '/content/drive/My Drive/googledrive/'
# TEMP = BASE_PATH + '/' + 'KsponSpeech_01' + '/' + 'KsponSpeech_0001' + '/' + 'KsponSpeech_000001' + '.txt'
# print(TEMP)

# with open(TEMP, 'r', encoding='ms949') as f:
#    r = f.read()
#    print(r)

# %%
def bracket_filter(sentence):
    new_sentence = ''
    flag = True

    for ch in sentence:
        if ch == '(':
            continue
        if ch == ')':
            if flag == True:
                flag = False
                continue
            else:
                flag = True
                continue
        if ch != ')' and flag == True:
            new_sentence += ch
            
    return new_sentence

# %%
# test = 'o/ 근데 (70%)/(칠십 퍼센트)가 커 보이긴 하는데 (200)/(이백) 벌다 (140)/(백 사십) 벌면 빠+ 빡셀걸? b/'
# print(bracket_filter(test))

# %%
def special_filter(sentence):
    SENTENCE_MARK = ['.', '?', ',', '!']
    NOISE = ['o', 'n', 'u', 'b', 'l']
    EXCEPT = ['/', '+', '*', '-', '@', '$', '^', '&', '[', ']', '=', ':', ';']

    import re
    
    new_sentence = ''
    for idx, ch in enumerate(sentence):
        if ch not in SENTENCE_MARK:
            # o/, n/ 등을 처리
            if idx + 1 < len(sentence) and ch in NOISE and sentence[idx+1] == '/':
                # '웃음(l/)'을 '^'로 처리
                if ch == 'l':
                    new_sentence += '^' 
                continue
        if ch == '+':
            new_sentence += ','
        if ch not in EXCEPT:
            new_sentence += ch
    pattern = re.compile(r'\s\s+')
    new_sentence = re.sub(pattern, ' ', new_sentence.strip())
    
    return new_sentence

# %%
# test = 'o/ 근데 (70%)/(칠십 퍼센트)가 커 보이긴 하는데 (200)/(이백) 벌다 (140)/(백 사십) 벌면 빠+ 빡셀걸? b/'
# print(special_filter(test))

# %%
def sentence_filter(raw_sentence):
    return special_filter(bracket_filter(raw_sentence))

# %%
# test = 'o/ 근데 (70%)/(칠십 퍼센트)가 커 보이긴 하는데 (200)/(이백) 벌다 (140)/(백 사십) 벌면 빠+ 빡셀걸? l/'
# print(sentence_filter(test))

# %%
# with open(TEMP, 'r', encoding='ms949') as f:
#    r = f.read()
#    print(sentence_filter(r))

# %% [markdown]
# ## 3. Create Character labels

# %%
import os
import pandas as pd

# BASE_PATH = '/content/drive/My Drive/googledrive/'
BASE_PATH = '../'

label_list = []
label_freq = []

temp = os.listdir(BASE_PATH)
f1_names = [t for t in temp if 'KsponSpeech_0' in t]
# f1_names = ['KsponSpeech_01'] ### test
print(f1_names)

for f1 in f1_names:
    print(f'----- {f1} started... ')
    f2_names = os.listdir(BASE_PATH + f1 + '/')
    for f2 in f2_names:
        if 'KsponSpeech_' not in f2:
            continue
        print(f'---------- {f2} started... ')
        f_names = os.listdir(BASE_PATH + f1 + '/' + f2 + '/')
        for fn in f_names:
            if ('.txt' not in fn) or ('_label_' in fn):
                continue
            with open(BASE_PATH + f1 + '/' + f2 + '/' + fn, 'r', encoding='ms949') as f:
                sentence = sentence_filter(f.readline())
            for ch in sentence:
                if ch not in label_list:
                    label_list.append(ch)
                    label_freq.append(1)
                else:
                    label_freq[label_list.index(ch)] += 1

print('\n\n')
print('----- ⚡ Create Label list/freq Ended !!!')
    
label_freq, label_list = zip(*sorted(zip(label_freq, label_list), reverse=True))
label = {'id': [0, 1, 2], 'char': ['_', '<s>', '</s>'], 'freq': [0, 0, 0]}
for idx, (ch, freq) in enumerate(zip(label_list, label_freq)):
    label['id'].append(idx+3)
    label['char'].append(ch)
    label['freq'].append(freq)

label_df = pd.DataFrame(label)
label_df.to_csv(BASE_PATH + 'aihub_labels.csv', encoding='ms949', index=False)

print('\n\n')
print('----- ⚡ Create aihub_labels Ended !!!')
print(label_df)
# Out:
# --------- KsponSpeech_0137 started...
# ---------- KsponSpeech_0138 started...
# ---------- KsponSpeech_0139 started...
# ---------- KsponSpeech_0140 started...
# ---------- KsponSpeech_0141 started...
# ---------- KsponSpeech_0142 started...
# ---------- KsponSpeech_0143 started...
# ---------- KsponSpeech_0144 started...
# ---------- KsponSpeech_0145 started...
# ---------- KsponSpeech_0146 started...
# ---------- KsponSpeech_0147 started...
# ---------- KsponSpeech_0148 started...
# ---------- KsponSpeech_0149 started...
# ---------- KsponSpeech_0150 started...
# ---------- KsponSpeech_0151 started...
# ---------- KsponSpeech_0152 started...
# ---------- KsponSpeech_0153 started...
# ---------- KsponSpeech_0154 started...
# ---------- KsponSpeech_0155 started...
# ---------- KsponSpeech_0156 started...
# ---------- KsponSpeech_0157 started...
# ---------- KsponSpeech_0158 started...
# ---------- KsponSpeech_0159 started...
# ---------- KsponSpeech_0160 started...
# ---------- KsponSpeech_0161 started...
# ---------- KsponSpeech_0162 started...
# ---------- KsponSpeech_0163 started...
# ---------- KsponSpeech_0164 started...
# ---------- KsponSpeech_0165 started...
# ---------- KsponSpeech_0166 started...
# ---------- KsponSpeech_0167 started...
# ---------- KsponSpeech_0168 started...
# ---------- KsponSpeech_0169 started...
# ---------- KsponSpeech_0170 started...
# ---------- KsponSpeech_0171 started...
# ---------- KsponSpeech_0172 started...
# ---------- KsponSpeech_0173 started...
# ---------- KsponSpeech_0174 started...
# ---------- KsponSpeech_0175 started...
# ---------- KsponSpeech_0176 started...
# ---------- KsponSpeech_0177 started...
# ---------- KsponSpeech_0178 started...
# ---------- KsponSpeech_0179 started...
# ---------- KsponSpeech_0180 started...
# ---------- KsponSpeech_0181 started...
# ---------- KsponSpeech_0182 started...
# ---------- KsponSpeech_0183 started...
# ---------- KsponSpeech_0184 started...
# ---------- KsponSpeech_0185 started...
# ---------- KsponSpeech_0186 started...
# ---------- KsponSpeech_0187 started...
# ---------- KsponSpeech_0188 started...
# ---------- KsponSpeech_0189 started...
# ---------- KsponSpeech_0190 started...
# ---------- KsponSpeech_0191 started...
# ---------- KsponSpeech_0192 started...
# ---------- KsponSpeech_0193 started...
# ---------- KsponSpeech_0194 started...
# ---------- KsponSpeech_0195 started...
# ---------- KsponSpeech_0196 started...
# ---------- KsponSpeech_0197 started...
# ---------- KsponSpeech_0198 started...
# ---------- KsponSpeech_0199 started...
# ---------- KsponSpeech_0200 started...
# ---------- KsponSpeech_0201 started...
# ---------- KsponSpeech_0202 started...
# ---------- KsponSpeech_0203 started...
# ---------- KsponSpeech_0204 started...
# ---------- KsponSpeech_0205 started...
# ---------- KsponSpeech_0206 started...
# ---------- KsponSpeech_0207 started...
# ---------- KsponSpeech_0208 started...
# ---------- KsponSpeech_0209 started...
# ---------- KsponSpeech_0210 started...
# ---------- KsponSpeech_0211 started...
# ---------- KsponSpeech_0212 started...
# ---------- KsponSpeech_0213 started...
# ---------- KsponSpeech_0214 started...
# ---------- KsponSpeech_0215 started...
# ---------- KsponSpeech_0216 started...
# ---------- KsponSpeech_0217 started...
# ---------- KsponSpeech_0218 started...
# ---------- KsponSpeech_0219 started...
# ---------- KsponSpeech_0220 started...
# ---------- KsponSpeech_0221 started...
# ---------- KsponSpeech_0222 started...
# ---------- KsponSpeech_0223 started...
# ---------- KsponSpeech_0224 started...
# ---------- KsponSpeech_0225 started...
# ---------- KsponSpeech_0226 started...
# ---------- KsponSpeech_0227 started...
# ---------- KsponSpeech_0228 started...
# ---------- KsponSpeech_0229 started...
# ---------- KsponSpeech_0230 started...
# ---------- KsponSpeech_0231 started...
# ---------- KsponSpeech_0232 started...
# ---------- KsponSpeech_0233 started...
# ---------- KsponSpeech_0234 started...
# ---------- KsponSpeech_0235 started...
# ---------- KsponSpeech_0236 started...
# ---------- KsponSpeech_0237 started...
# ---------- KsponSpeech_0238 started...
# ---------- KsponSpeech_0239 started...
# ---------- KsponSpeech_0240 started...
# ---------- KsponSpeech_0241 started...
# ---------- KsponSpeech_0242 started...
# ---------- KsponSpeech_0243 started...
# ---------- KsponSpeech_0244 started...
# ---------- KsponSpeech_0245 started...
# ---------- KsponSpeech_0246 started...
# ---------- KsponSpeech_0247 started...
# ---------- KsponSpeech_0248 started...
# ----- KsponSpeech_03 started...
# ---------- KsponSpeech_0249 started...
# ---------- KsponSpeech_0250 started...
# ---------- KsponSpeech_0251 started...
# ---------- KsponSpeech_0252 started...
# ---------- KsponSpeech_0253 started...
# ---------- KsponSpeech_0254 started...
# ---------- KsponSpeech_0255 started...
# ---------- KsponSpeech_0256 started...
# ---------- KsponSpeech_0257 started...
# ---------- KsponSpeech_0258 started...
# ---------- KsponSpeech_0259 started...
# ---------- KsponSpeech_0260 started...
# ---------- KsponSpeech_0261 started...
# ---------- KsponSpeech_0262 started...
# ---------- KsponSpeech_0263 started...
# ---------- KsponSpeech_0264 started...
# ---------- KsponSpeech_0265 started...
# ---------- KsponSpeech_0266 started...
# ---------- KsponSpeech_0267 started...
# ---------- KsponSpeech_0268 started...
# ---------- KsponSpeech_0269 started...
# ---------- KsponSpeech_0270 started...
# ---------- KsponSpeech_0271 started...
# ---------- KsponSpeech_0272 started...
# ---------- KsponSpeech_0273 started...
# ---------- KsponSpeech_0274 started...
# ---------- KsponSpeech_0275 started...
# ---------- KsponSpeech_0276 started...
# ---------- KsponSpeech_0277 started...
# ---------- KsponSpeech_0278 started...
# ---------- KsponSpeech_0279 started...
# ---------- KsponSpeech_0280 started...
# ---------- KsponSpeech_0281 started...
# ---------- KsponSpeech_0282 started...
# ---------- KsponSpeech_0283 started...
# ---------- KsponSpeech_0284 started...
# ---------- KsponSpeech_0285 started...
# ---------- KsponSpeech_0286 started...
# ---------- KsponSpeech_0287 started...
# ---------- KsponSpeech_0288 started...
# ---------- KsponSpeech_0289 started...
# ---------- KsponSpeech_0290 started...
# ---------- KsponSpeech_0291 started...
# ---------- KsponSpeech_0292 started...
# ---------- KsponSpeech_0293 started...
# ---------- KsponSpeech_0294 started...
# ---------- KsponSpeech_0295 started...
# ---------- KsponSpeech_0296 started...
# ---------- KsponSpeech_0297 started...
# ---------- KsponSpeech_0298 started...
# ---------- KsponSpeech_0299 started...
# ---------- KsponSpeech_0300 started...
# ---------- KsponSpeech_0301 started...
# ---------- KsponSpeech_0302 started...
# ---------- KsponSpeech_0303 started...
# ---------- KsponSpeech_0304 started...
# ---------- KsponSpeech_0305 started...
# ---------- KsponSpeech_0306 started...
# ---------- KsponSpeech_0307 started...
# ---------- KsponSpeech_0308 started...
# ---------- KsponSpeech_0309 started...
# ---------- KsponSpeech_0310 started...
# ---------- KsponSpeech_0311 started...
# ---------- KsponSpeech_0312 started...
# ---------- KsponSpeech_0313 started...
# ---------- KsponSpeech_0314 started...
# ---------- KsponSpeech_0315 started...
# ---------- KsponSpeech_0316 started...
# ---------- KsponSpeech_0317 started...
# ---------- KsponSpeech_0318 started...
# ---------- KsponSpeech_0319 started...
# ---------- KsponSpeech_0320 started...
# ---------- KsponSpeech_0321 started...
# ---------- KsponSpeech_0322 started...
# ---------- KsponSpeech_0323 started...
# ---------- KsponSpeech_0324 started...
# ---------- KsponSpeech_0325 started...
# ---------- KsponSpeech_0326 started...
# ---------- KsponSpeech_0327 started...
# ---------- KsponSpeech_0328 started...
# ---------- KsponSpeech_0329 started...
# ---------- KsponSpeech_0330 started...
# ---------- KsponSpeech_0331 started...
# ---------- KsponSpeech_0332 started...
# ---------- KsponSpeech_0333 started...
# ---------- KsponSpeech_0334 started...
# ---------- KsponSpeech_0335 started...
# ---------- KsponSpeech_0336 started...
# ---------- KsponSpeech_0337 started...
# ---------- KsponSpeech_0338 started...
# ---------- KsponSpeech_0339 started...
# ---------- KsponSpeech_0340 started...
# ---------- KsponSpeech_0341 started...
# ---------- KsponSpeech_0342 started...
# ---------- KsponSpeech_0343 started...
# ---------- KsponSpeech_0344 started...
# ---------- KsponSpeech_0345 started...
# ---------- KsponSpeech_0346 started...
# ---------- KsponSpeech_0347 started...
# ---------- KsponSpeech_0348 started...
# ---------- KsponSpeech_0349 started...
# ---------- KsponSpeech_0350 started...
# ---------- KsponSpeech_0351 started...
# ---------- KsponSpeech_0352 started...
# ---------- KsponSpeech_0353 started...
# ---------- KsponSpeech_0354 started...
# ---------- KsponSpeech_0355 started...
# ---------- KsponSpeech_0356 started...
# ---------- KsponSpeech_0357 started...
# ---------- KsponSpeech_0358 started...
# ---------- KsponSpeech_0359 started...
# ---------- KsponSpeech_0360 started...
# ---------- KsponSpeech_0361 started...
# ---------- KsponSpeech_0362 started...
# ---------- KsponSpeech_0363 started...
# ---------- KsponSpeech_0364 started...
# ---------- KsponSpeech_0365 started...
# ---------- KsponSpeech_0366 started...
# ---------- KsponSpeech_0367 started...
# ---------- KsponSpeech_0368 started...
# ---------- KsponSpeech_0369 started...
# ---------- KsponSpeech_0370 started...
# ---------- KsponSpeech_0371 started...
# ---------- KsponSpeech_0372 started...
# ----- KsponSpeech_04 started...
# ---------- KsponSpeech_0373 started...
# ---------- KsponSpeech_0374 started...
# ---------- KsponSpeech_0375 started...
# ---------- KsponSpeech_0376 started...
# ---------- KsponSpeech_0377 started...
# ---------- KsponSpeech_0378 started...
# ---------- KsponSpeech_0379 started...
# ---------- KsponSpeech_0380 started...
# ---------- KsponSpeech_0381 started...
# ---------- KsponSpeech_0382 started...
# ---------- KsponSpeech_0383 started...
# ---------- KsponSpeech_0384 started...
# ---------- KsponSpeech_0385 started...
# ---------- KsponSpeech_0386 started...
# ---------- KsponSpeech_0387 started...
# ---------- KsponSpeech_0388 started...
# ---------- KsponSpeech_0389 started...
# ---------- KsponSpeech_0390 started...
# ---------- KsponSpeech_0391 started...
# ---------- KsponSpeech_0392 started...
# ---------- KsponSpeech_0393 started...
# ---------- KsponSpeech_0394 started...
# ---------- KsponSpeech_0395 started...
# ---------- KsponSpeech_0396 started...
# ---------- KsponSpeech_0397 started...
# ---------- KsponSpeech_0398 started...
# ---------- KsponSpeech_0399 started...
# ---------- KsponSpeech_0400 started...
# ---------- KsponSpeech_0401 started...
# ---------- KsponSpeech_0402 started...
# ---------- KsponSpeech_0403 started...
# ---------- KsponSpeech_0404 started...
# ---------- KsponSpeech_0405 started...
# ---------- KsponSpeech_0406 started...
# ---------- KsponSpeech_0407 started...
# ---------- KsponSpeech_0408 started...
# ---------- KsponSpeech_0409 started...
# ---------- KsponSpeech_0410 started...
# ---------- KsponSpeech_0411 started...
# ---------- KsponSpeech_0412 started...
# ---------- KsponSpeech_0413 started...
# ---------- KsponSpeech_0414 started...
# ---------- KsponSpeech_0415 started...
# ---------- KsponSpeech_0416 started...
# ---------- KsponSpeech_0417 started...
# ---------- KsponSpeech_0418 started...
# ---------- KsponSpeech_0419 started...
# ---------- KsponSpeech_0420 started...
# ---------- KsponSpeech_0421 started...
# ---------- KsponSpeech_0422 started...
# ---------- KsponSpeech_0423 started...
# ---------- KsponSpeech_0424 started...
# ---------- KsponSpeech_0425 started...
# ---------- KsponSpeech_0426 started...
# ---------- KsponSpeech_0427 started...
# ---------- KsponSpeech_0428 started...
# ---------- KsponSpeech_0429 started...
# ---------- KsponSpeech_0430 started...
# ---------- KsponSpeech_0431 started...
# ---------- KsponSpeech_0432 started...
# ---------- KsponSpeech_0433 started...
# ---------- KsponSpeech_0434 started...
# ---------- KsponSpeech_0435 started...
# ---------- KsponSpeech_0436 started...
# ---------- KsponSpeech_0437 started...
# ---------- KsponSpeech_0438 started...
# ---------- KsponSpeech_0439 started...
# ---------- KsponSpeech_0440 started...
# ---------- KsponSpeech_0441 started...
# ---------- KsponSpeech_0442 started...
# ---------- KsponSpeech_0443 started...
# ---------- KsponSpeech_0444 started...
# ---------- KsponSpeech_0445 started...
# ---------- KsponSpeech_0446 started...
# ---------- KsponSpeech_0447 started...
# ---------- KsponSpeech_0448 started...
# ---------- KsponSpeech_0449 started...
# ---------- KsponSpeech_0450 started...
# ---------- KsponSpeech_0451 started...
# ---------- KsponSpeech_0452 started...
# ---------- KsponSpeech_0453 started...
# ---------- KsponSpeech_0454 started...
# ---------- KsponSpeech_0455 started...
# ---------- KsponSpeech_0456 started...
# ---------- KsponSpeech_0457 started...
# ---------- KsponSpeech_0458 started...
# ---------- KsponSpeech_0459 started...
# ---------- KsponSpeech_0460 started...
# ---------- KsponSpeech_0461 started...
# ---------- KsponSpeech_0462 started...
# ---------- KsponSpeech_0463 started...
# ---------- KsponSpeech_0464 started...
# ---------- KsponSpeech_0465 started...
# ---------- KsponSpeech_0466 started...
# ---------- KsponSpeech_0467 started...
# ---------- KsponSpeech_0468 started...
# ---------- KsponSpeech_0469 started...
# ---------- KsponSpeech_0470 started...
# ---------- KsponSpeech_0471 started...
# ---------- KsponSpeech_0472 started...
# ---------- KsponSpeech_0473 started...
# ---------- KsponSpeech_0474 started...
# ---------- KsponSpeech_0475 started...
# ---------- KsponSpeech_0476 started...
# ---------- KsponSpeech_0477 started...
# ---------- KsponSpeech_0478 started...
# ---------- KsponSpeech_0479 started...
# ---------- KsponSpeech_0480 started...
# ---------- KsponSpeech_0481 started...
# ---------- KsponSpeech_0482 started...
# ---------- KsponSpeech_0483 started...
# ---------- KsponSpeech_0484 started...
# ---------- KsponSpeech_0485 started...
# ---------- KsponSpeech_0486 started...
# ---------- KsponSpeech_0487 started...
# ---------- KsponSpeech_0488 started...
# ---------- KsponSpeech_0489 started...
# ---------- KsponSpeech_0490 started...
# ---------- KsponSpeech_0491 started...
# ---------- KsponSpeech_0492 started...
# ---------- KsponSpeech_0493 started...
# ---------- KsponSpeech_0494 started...
# ---------- KsponSpeech_0495 started...
# ---------- KsponSpeech_0496 started...
# ----- KsponSpeech_05 started...
# ---------- KsponSpeech_0497 started...
# ---------- KsponSpeech_0498 started...
# ---------- KsponSpeech_0499 started...
# ---------- KsponSpeech_0500 started...
# ---------- KsponSpeech_0501 started...
# ---------- KsponSpeech_0502 started...
# ---------- KsponSpeech_0503 started...
# ---------- KsponSpeech_0504 started...
# ---------- KsponSpeech_0505 started...
# ---------- KsponSpeech_0506 started...
# ---------- KsponSpeech_0507 started...
# ---------- KsponSpeech_0508 started...
# ---------- KsponSpeech_0509 started...
# ---------- KsponSpeech_0510 started...
# ---------- KsponSpeech_0511 started...
# ---------- KsponSpeech_0512 started...
# ---------- KsponSpeech_0513 started...
# ---------- KsponSpeech_0514 started...
# ---------- KsponSpeech_0515 started...
# ---------- KsponSpeech_0516 started...
# ---------- KsponSpeech_0517 started...
# ---------- KsponSpeech_0518 started...
# ---------- KsponSpeech_0519 started...
# ---------- KsponSpeech_0520 started...
# ---------- KsponSpeech_0521 started...
# ---------- KsponSpeech_0522 started...
# ---------- KsponSpeech_0523 started...
# ---------- KsponSpeech_0524 started...
# ---------- KsponSpeech_0525 started...
# ---------- KsponSpeech_0526 started...
# ---------- KsponSpeech_0527 started...
# ---------- KsponSpeech_0528 started...
# ---------- KsponSpeech_0529 started...
# ---------- KsponSpeech_0530 started...
# ---------- KsponSpeech_0531 started...
# ---------- KsponSpeech_0532 started...
# ---------- KsponSpeech_0533 started...
# ---------- KsponSpeech_0534 started...
# ---------- KsponSpeech_0535 started...
# ---------- KsponSpeech_0536 started...
# ---------- KsponSpeech_0537 started...
# ---------- KsponSpeech_0538 started...
# ---------- KsponSpeech_0539 started...
# ---------- KsponSpeech_0540 started...
# ---------- KsponSpeech_0541 started...
# ---------- KsponSpeech_0542 started...
# ---------- KsponSpeech_0543 started...
# ---------- KsponSpeech_0544 started...
# ---------- KsponSpeech_0545 started...
# ---------- KsponSpeech_0546 started...
# ---------- KsponSpeech_0547 started...
# ---------- KsponSpeech_0548 started...
# ---------- KsponSpeech_0549 started...
# ---------- KsponSpeech_0550 started...
# ---------- KsponSpeech_0551 started...
# ---------- KsponSpeech_0552 started...
# ---------- KsponSpeech_0553 started...
# ---------- KsponSpeech_0554 started...
# ---------- KsponSpeech_0555 started...
# ---------- KsponSpeech_0556 started...
# ---------- KsponSpeech_0557 started...
# ---------- KsponSpeech_0558 started...
# ---------- KsponSpeech_0559 started...
# ---------- KsponSpeech_0560 started...
# ---------- KsponSpeech_0561 started...
# ---------- KsponSpeech_0562 started...
# ---------- KsponSpeech_0563 started...
# ---------- KsponSpeech_0564 started...
# ---------- KsponSpeech_0565 started...
# ---------- KsponSpeech_0566 started...
# ---------- KsponSpeech_0567 started...
# ---------- KsponSpeech_0568 started...
# ---------- KsponSpeech_0569 started...
# ---------- KsponSpeech_0570 started...
# ---------- KsponSpeech_0571 started...
# ---------- KsponSpeech_0572 started...
# ---------- KsponSpeech_0573 started...
# ---------- KsponSpeech_0574 started...
# ---------- KsponSpeech_0575 started...
# ---------- KsponSpeech_0576 started...
# ---------- KsponSpeech_0577 started...
# ---------- KsponSpeech_0578 started...
# ---------- KsponSpeech_0579 started...
# ---------- KsponSpeech_0580 started...
# ---------- KsponSpeech_0581 started...
# ---------- KsponSpeech_0582 started...
# ---------- KsponSpeech_0583 started...
# ---------- KsponSpeech_0584 started...
# ---------- KsponSpeech_0585 started...
# ---------- KsponSpeech_0586 started...
# ---------- KsponSpeech_0587 started...
# ---------- KsponSpeech_0588 started...
# ---------- KsponSpeech_0589 started...
# ---------- KsponSpeech_0590 started...
# ---------- KsponSpeech_0591 started...
# ---------- KsponSpeech_0592 started...
# ---------- KsponSpeech_0593 started...
# ---------- KsponSpeech_0594 started...
# ---------- KsponSpeech_0595 started...
# ---------- KsponSpeech_0596 started...
# ---------- KsponSpeech_0597 started...
# ---------- KsponSpeech_0598 started...
# ---------- KsponSpeech_0599 started...
# ---------- KsponSpeech_0600 started...
# ---------- KsponSpeech_0601 started...
# ---------- KsponSpeech_0602 started...
# ---------- KsponSpeech_0603 started...
# ---------- KsponSpeech_0604 started...
# ---------- KsponSpeech_0605 started...
# ---------- KsponSpeech_0606 started...
# ---------- KsponSpeech_0607 started...
# ---------- KsponSpeech_0608 started...
# ---------- KsponSpeech_0609 started...
# ---------- KsponSpeech_0610 started...
# ---------- KsponSpeech_0611 started...
# ---------- KsponSpeech_0612 started...
# ---------- KsponSpeech_0613 started...
# ---------- KsponSpeech_0614 started...
# ---------- KsponSpeech_0615 started...
# ---------- KsponSpeech_0616 started...
# ---------- KsponSpeech_0617 started...
# ---------- KsponSpeech_0618 started...
# ---------- KsponSpeech_0619 started...
# ---------- KsponSpeech_0620 started...
# ---------- KsponSpeech_0621 started...
# ---------- KsponSpeech_0622 started...
# ---------- KsponSpeech_0623 started...
#
#
#
# ----- ⚡ Create Label list/freq Ended !!!
#
#
#
# ----- ⚡ Create aihub_labels Ended !!!
#         id  char     freq
# 0        0     _        0
# 1        1   <s>        0
# 2        2  </s>        0
# 3        3        5729604
# 4        4     .   641656
# ...    ...   ...      ...
# 2336  2336     걉        1
# 2337  2337     걈        1
# 2338  2338     갹        1
# 2339  2339     갗        1
# 2340  2340     #        1
#
# [2341 rows x 3 columns]

# %% [markdown]
# ## 4. Create target text

# %%
import pandas as pd

def load_label(file_path):
    char2id = {}
    id2char = {}
    ch_labels = pd.read_csv(file_path, encoding='ms949')
    id_list = ch_labels['id']
    char_list = ch_labels['char']
    freq_list = ch_labels['freq']

    for (id, char, freq) in zip(id_list, char_list, freq_list):
        char2id[char] = id
        id2char[id] = char
    return char2id, id2char

# %%
def sentence_to_target(sentence, char2id):
    target = ''
    for ch in sentence:
        target += (str(char2id[ch]) + ' ')
    return target[:-1]

# %%
def target_to_sentence(target, id2char):
    sentence = ''
    targets = target.split()

    for n in targets:
        sentence += id2char[int(n)]
        
    return sentence

# %%
# file_path = '/content/aihub_labels.csv'
# char2id, id2char = load_label(file_path)

# test = '오늘 뭐 먹지?'

# a = sentence_to_target(test, char2id)
# print(a)

# b = target_to_sentence(a, id2char)
# print(b)

# %%
import pandas as pd
import os

'''
BASE_PATH = '/content/drive/My Drive/googledrive/'

temp = os.listdir(BASE_PATH)
# f1_names = [t for t in temp if 'KsponSpeech_0' in t]
f1_names = ['KsponSpeech_01'] ### test
print(f1_names)
'''

char2id, id2char = load_label(BASE_PATH + 'aihub_labels.csv')
total_fn = 0

for f1 in f1_names:
    print(f'----- {f1} started... ')
    f2_names = os.listdir(BASE_PATH + f1 + '/')
    for f2 in f2_names:
        if 'KsponSpeech_' not in f2:
            continue
        print(f'---------- {f2} started... ')
        f_names = os.listdir(BASE_PATH + f1 + '/' + f2 + '/')
        for fn in f_names:
            if ('.txt' not in fn) or ('_label_' in fn):
                continue
            total_fn += 1
            with open(BASE_PATH + f1 + '/' + f2 + '/' + fn, 'r', encoding='ms949') as f:
                sentence = sentence_filter(f.readline())
            with open(BASE_PATH + f1 + '/' + f2 + '/' + 'KsponSpeech_label_' + fn.split('_')[1][:6] + '.txt', 'w', encoding='ms949') as f:
                target = sentence_to_target(sentence, char2id)
                f.write(target)
    
print('\n\n')
print(f'total_fn: {total_fn}')
print('----- ⚡Create Target Text Ended !!! ')
# Out:
# ..
# ---------- KsponSpeech_0128 started...
# ---------- KsponSpeech_0129 started...
# ---------- KsponSpeech_0130 started...
# ---------- KsponSpeech_0131 started...
# ---------- KsponSpeech_0132 started...
# ---------- KsponSpeech_0133 started...
# ---------- KsponSpeech_0134 started...
# ---------- KsponSpeech_0135 started...
# ---------- KsponSpeech_0136 started...
# ---------- KsponSpeech_0137 started...
# ---------- KsponSpeech_0138 started...
# ---------- KsponSpeech_0139 started...
# ---------- KsponSpeech_0140 started...
# ---------- KsponSpeech_0141 started...
# ---------- KsponSpeech_0142 started...
# ---------- KsponSpeech_0143 started...
# ---------- KsponSpeech_0144 started...
# ---------- KsponSpeech_0145 started...
# ---------- KsponSpeech_0146 started...
# ---------- KsponSpeech_0147 started...
# ---------- KsponSpeech_0148 started...
# ---------- KsponSpeech_0149 started...
# ---------- KsponSpeech_0150 started...
# ---------- KsponSpeech_0151 started...
# ---------- KsponSpeech_0152 started...
# ---------- KsponSpeech_0153 started...
# ---------- KsponSpeech_0154 started...
# ---------- KsponSpeech_0155 started...
# ---------- KsponSpeech_0156 started...
# ---------- KsponSpeech_0157 started...
# ---------- KsponSpeech_0158 started...
# ---------- KsponSpeech_0159 started...
# ---------- KsponSpeech_0160 started...
# ---------- KsponSpeech_0161 started...
# ---------- KsponSpeech_0162 started...
# ---------- KsponSpeech_0163 started...
# ---------- KsponSpeech_0164 started...
# ---------- KsponSpeech_0165 started...
# ---------- KsponSpeech_0166 started...
# ---------- KsponSpeech_0167 started...
# ---------- KsponSpeech_0168 started...
# ---------- KsponSpeech_0169 started...
# ---------- KsponSpeech_0170 started...
# ---------- KsponSpeech_0171 started...
# ---------- KsponSpeech_0172 started...
# ---------- KsponSpeech_0173 started...
# ---------- KsponSpeech_0174 started...
# ---------- KsponSpeech_0175 started...
# ---------- KsponSpeech_0176 started...
# ---------- KsponSpeech_0177 started...
# ---------- KsponSpeech_0178 started...
# ---------- KsponSpeech_0179 started...
# ---------- KsponSpeech_0180 started...
# ---------- KsponSpeech_0181 started...
# ---------- KsponSpeech_0182 started...
# ---------- KsponSpeech_0183 started...
# ---------- KsponSpeech_0184 started...
# ---------- KsponSpeech_0185 started...
# ---------- KsponSpeech_0186 started...
# ---------- KsponSpeech_0187 started...
# ---------- KsponSpeech_0188 started...
# ---------- KsponSpeech_0189 started...
# ---------- KsponSpeech_0190 started...
# ---------- KsponSpeech_0191 started...
# ---------- KsponSpeech_0192 started...
# ---------- KsponSpeech_0193 started...
# ---------- KsponSpeech_0194 started...
# ---------- KsponSpeech_0195 started...
# ---------- KsponSpeech_0196 started...
# ---------- KsponSpeech_0197 started...
# ---------- KsponSpeech_0198 started...
# ---------- KsponSpeech_0199 started...
# ---------- KsponSpeech_0200 started...
# ---------- KsponSpeech_0201 started...
# ---------- KsponSpeech_0202 started...
# ---------- KsponSpeech_0203 started...
# ---------- KsponSpeech_0204 started...
# ---------- KsponSpeech_0205 started...
# ---------- KsponSpeech_0206 started...
# ---------- KsponSpeech_0207 started...
# ---------- KsponSpeech_0208 started...
# ---------- KsponSpeech_0209 started...
# ---------- KsponSpeech_0210 started...
# ---------- KsponSpeech_0211 started...
# ---------- KsponSpeech_0212 started...
# ---------- KsponSpeech_0213 started...
# ---------- KsponSpeech_0214 started...
# ---------- KsponSpeech_0215 started...
# ---------- KsponSpeech_0216 started...
# ---------- KsponSpeech_0217 started...
# ---------- KsponSpeech_0218 started...
# ---------- KsponSpeech_0219 started...
# ---------- KsponSpeech_0220 started...
# ---------- KsponSpeech_0221 started...
# ---------- KsponSpeech_0222 started...
# ---------- KsponSpeech_0223 started...
# ---------- KsponSpeech_0224 started...
# ---------- KsponSpeech_0225 started...
# ---------- KsponSpeech_0226 started...
# ---------- KsponSpeech_0227 started...
# ---------- KsponSpeech_0228 started...
# ---------- KsponSpeech_0229 started...
# ---------- KsponSpeech_0230 started...
# ---------- KsponSpeech_0231 started...
# ---------- KsponSpeech_0232 started...
# ---------- KsponSpeech_0233 started...
# ---------- KsponSpeech_0234 started...
# ---------- KsponSpeech_0235 started...
# ---------- KsponSpeech_0236 started...
# ---------- KsponSpeech_0237 started...
# ---------- KsponSpeech_0238 started...
# ---------- KsponSpeech_0239 started...
# ---------- KsponSpeech_0240 started...
# ---------- KsponSpeech_0241 started...
# ---------- KsponSpeech_0242 started...
# ---------- KsponSpeech_0243 started...
# ---------- KsponSpeech_0244 started...
# ---------- KsponSpeech_0245 started...
# ---------- KsponSpeech_0246 started...
# ---------- KsponSpeech_0247 started...
# ---------- KsponSpeech_0248 started...
# ----- KsponSpeech_03 started...
# ---------- KsponSpeech_0249 started...
# ---------- KsponSpeech_0250 started...
# ---------- KsponSpeech_0251 started...
# ---------- KsponSpeech_0252 started...
# ---------- KsponSpeech_0253 started...
# ---------- KsponSpeech_0254 started...
# ---------- KsponSpeech_0255 started...
# ---------- KsponSpeech_0256 started...
# ---------- KsponSpeech_0257 started...
# ---------- KsponSpeech_0258 started...
# ---------- KsponSpeech_0259 started...
# ---------- KsponSpeech_0260 started...
# ---------- KsponSpeech_0261 started...
# ---------- KsponSpeech_0262 started...
# ---------- KsponSpeech_0263 started...
# ---------- KsponSpeech_0264 started...
# ---------- KsponSpeech_0265 started...
# ---------- KsponSpeech_0266 started...
# ---------- KsponSpeech_0267 started...
# ---------- KsponSpeech_0268 started...
# ---------- KsponSpeech_0269 started...
# ---------- KsponSpeech_0270 started...
# ---------- KsponSpeech_0271 started...
# ---------- KsponSpeech_0272 started...
# ---------- KsponSpeech_0273 started...
# ---------- KsponSpeech_0274 started...
# ---------- KsponSpeech_0275 started...
# ---------- KsponSpeech_0276 started...
# ---------- KsponSpeech_0277 started...
# ---------- KsponSpeech_0278 started...
# ---------- KsponSpeech_0279 started...
# ---------- KsponSpeech_0280 started...
# ---------- KsponSpeech_0281 started...
# ---------- KsponSpeech_0282 started...
# ---------- KsponSpeech_0283 started...
# ---------- KsponSpeech_0284 started...
# ---------- KsponSpeech_0285 started...
# ---------- KsponSpeech_0286 started...
# ---------- KsponSpeech_0287 started...
# ---------- KsponSpeech_0288 started...
# ---------- KsponSpeech_0289 started...
# ---------- KsponSpeech_0290 started...
# ---------- KsponSpeech_0291 started...
# ---------- KsponSpeech_0292 started...
# ---------- KsponSpeech_0293 started...
# ---------- KsponSpeech_0294 started...
# ---------- KsponSpeech_0295 started...
# ---------- KsponSpeech_0296 started...
# ---------- KsponSpeech_0297 started...
# ---------- KsponSpeech_0298 started...
# ---------- KsponSpeech_0299 started...
# ---------- KsponSpeech_0300 started...
# ---------- KsponSpeech_0301 started...
# ---------- KsponSpeech_0302 started...
# ---------- KsponSpeech_0303 started...
# ---------- KsponSpeech_0304 started...
# ---------- KsponSpeech_0305 started...
# ---------- KsponSpeech_0306 started...
# ---------- KsponSpeech_0307 started...
# ---------- KsponSpeech_0308 started...
# ---------- KsponSpeech_0309 started...
# ---------- KsponSpeech_0310 started...
# ---------- KsponSpeech_0311 started...
# ---------- KsponSpeech_0312 started...
# ---------- KsponSpeech_0313 started...
# ---------- KsponSpeech_0314 started...
# ---------- KsponSpeech_0315 started...
# ---------- KsponSpeech_0316 started...
# ---------- KsponSpeech_0317 started...
# ---------- KsponSpeech_0318 started...
# ---------- KsponSpeech_0319 started...
# ---------- KsponSpeech_0320 started...
# ---------- KsponSpeech_0321 started...
# ---------- KsponSpeech_0322 started...
# ---------- KsponSpeech_0323 started...
# ---------- KsponSpeech_0324 started...
# ---------- KsponSpeech_0325 started...
# ---------- KsponSpeech_0326 started...
# ---------- KsponSpeech_0327 started...
# ---------- KsponSpeech_0328 started...
# ---------- KsponSpeech_0329 started...
# ---------- KsponSpeech_0330 started...
# ---------- KsponSpeech_0331 started...
# ---------- KsponSpeech_0332 started...
# ---------- KsponSpeech_0333 started...
# ---------- KsponSpeech_0334 started...
# ---------- KsponSpeech_0335 started...
# ---------- KsponSpeech_0336 started...
# ---------- KsponSpeech_0337 started...
# ---------- KsponSpeech_0338 started...
# ---------- KsponSpeech_0339 started...
# ---------- KsponSpeech_0340 started...
# ---------- KsponSpeech_0341 started...
# ---------- KsponSpeech_0342 started...
# ---------- KsponSpeech_0343 started...
# ---------- KsponSpeech_0344 started...
# ---------- KsponSpeech_0345 started...
# ---------- KsponSpeech_0346 started...
# ---------- KsponSpeech_0347 started...
# ---------- KsponSpeech_0348 started...
# ---------- KsponSpeech_0349 started...
# ---------- KsponSpeech_0350 started...
# ---------- KsponSpeech_0351 started...
# ---------- KsponSpeech_0352 started...
# ---------- KsponSpeech_0353 started...
# ---------- KsponSpeech_0354 started...
# ---------- KsponSpeech_0355 started...
# ---------- KsponSpeech_0356 started...
# ---------- KsponSpeech_0357 started...
# ---------- KsponSpeech_0358 started...
# ---------- KsponSpeech_0359 started...
# ---------- KsponSpeech_0360 started...
# ---------- KsponSpeech_0361 started...
# ---------- KsponSpeech_0362 started...
# ---------- KsponSpeech_0363 started...
# ---------- KsponSpeech_0364 started...
# ---------- KsponSpeech_0365 started...
# ---------- KsponSpeech_0366 started...
# ---------- KsponSpeech_0367 started...
# ---------- KsponSpeech_0368 started...
# ---------- KsponSpeech_0369 started...
# ---------- KsponSpeech_0370 started...
# ---------- KsponSpeech_0371 started...
# ---------- KsponSpeech_0372 started...
# ----- KsponSpeech_04 started...
# ---------- KsponSpeech_0373 started...
# ---------- KsponSpeech_0374 started...
# ---------- KsponSpeech_0375 started...
# ---------- KsponSpeech_0376 started...
# ---------- KsponSpeech_0377 started...
# ---------- KsponSpeech_0378 started...
# ---------- KsponSpeech_0379 started...
# ---------- KsponSpeech_0380 started...
# ---------- KsponSpeech_0381 started...
# ---------- KsponSpeech_0382 started...
# ---------- KsponSpeech_0383 started...
# ---------- KsponSpeech_0384 started...
# ---------- KsponSpeech_0385 started...
# ---------- KsponSpeech_0386 started...
# ---------- KsponSpeech_0387 started...
# ---------- KsponSpeech_0388 started...
# ---------- KsponSpeech_0389 started...
# ---------- KsponSpeech_0390 started...
# ---------- KsponSpeech_0391 started...
# ---------- KsponSpeech_0392 started...
# ---------- KsponSpeech_0393 started...
# ---------- KsponSpeech_0394 started...
# ---------- KsponSpeech_0395 started...
# ---------- KsponSpeech_0396 started...
# ---------- KsponSpeech_0397 started...
# ---------- KsponSpeech_0398 started...
# ---------- KsponSpeech_0399 started...
# ---------- KsponSpeech_0400 started...
# ---------- KsponSpeech_0401 started...
# ---------- KsponSpeech_0402 started...
# ---------- KsponSpeech_0403 started...
# ---------- KsponSpeech_0404 started...
# ---------- KsponSpeech_0405 started...
# ---------- KsponSpeech_0406 started...
# ---------- KsponSpeech_0407 started...
# ---------- KsponSpeech_0408 started...
# ---------- KsponSpeech_0409 started...
# ---------- KsponSpeech_0410 started...
# ---------- KsponSpeech_0411 started...
# ---------- KsponSpeech_0412 started...
# ---------- KsponSpeech_0413 started...
# ---------- KsponSpeech_0414 started...
# ---------- KsponSpeech_0415 started...
# ---------- KsponSpeech_0416 started...
# ---------- KsponSpeech_0417 started...
# ---------- KsponSpeech_0418 started...
# ---------- KsponSpeech_0419 started...
# ---------- KsponSpeech_0420 started...
# ---------- KsponSpeech_0421 started...
# ---------- KsponSpeech_0422 started...
# ---------- KsponSpeech_0423 started...
# ---------- KsponSpeech_0424 started...
# ---------- KsponSpeech_0425 started...
# ---------- KsponSpeech_0426 started...
# ---------- KsponSpeech_0427 started...
# ---------- KsponSpeech_0428 started...
# ---------- KsponSpeech_0429 started...
# ---------- KsponSpeech_0430 started...
# ---------- KsponSpeech_0431 started...
# ---------- KsponSpeech_0432 started...
# ---------- KsponSpeech_0433 started...
# ---------- KsponSpeech_0434 started...
# ---------- KsponSpeech_0435 started...
# ---------- KsponSpeech_0436 started...
# ---------- KsponSpeech_0437 started...
# ---------- KsponSpeech_0438 started...
# ---------- KsponSpeech_0439 started...
# ---------- KsponSpeech_0440 started...
# ---------- KsponSpeech_0441 started...
# ---------- KsponSpeech_0442 started...
# ---------- KsponSpeech_0443 started...
# ---------- KsponSpeech_0444 started...
# ---------- KsponSpeech_0445 started...
# ---------- KsponSpeech_0446 started...
# ---------- KsponSpeech_0447 started...
# ---------- KsponSpeech_0448 started...
# ---------- KsponSpeech_0449 started...
# ---------- KsponSpeech_0450 started...
# ---------- KsponSpeech_0451 started...
# ---------- KsponSpeech_0452 started...
# ---------- KsponSpeech_0453 started...
# ---------- KsponSpeech_0454 started...
# ---------- KsponSpeech_0455 started...
# ---------- KsponSpeech_0456 started...
# ---------- KsponSpeech_0457 started...
# ---------- KsponSpeech_0458 started...
# ---------- KsponSpeech_0459 started...
# ---------- KsponSpeech_0460 started...
# ---------- KsponSpeech_0461 started...
# ---------- KsponSpeech_0462 started...
# ---------- KsponSpeech_0463 started...
# ---------- KsponSpeech_0464 started...
# ---------- KsponSpeech_0465 started...
# ---------- KsponSpeech_0466 started...
# ---------- KsponSpeech_0467 started...
# ---------- KsponSpeech_0468 started...
# ---------- KsponSpeech_0469 started...
# ---------- KsponSpeech_0470 started...
# ---------- KsponSpeech_0471 started...
# ---------- KsponSpeech_0472 started...
# ---------- KsponSpeech_0473 started...
# ---------- KsponSpeech_0474 started...
# ---------- KsponSpeech_0475 started...
# ---------- KsponSpeech_0476 started...
# ---------- KsponSpeech_0477 started...
# ---------- KsponSpeech_0478 started...
# ---------- KsponSpeech_0479 started...
# ---------- KsponSpeech_0480 started...
# ---------- KsponSpeech_0481 started...
# ---------- KsponSpeech_0482 started...
# ---------- KsponSpeech_0483 started...
# ---------- KsponSpeech_0484 started...
# ---------- KsponSpeech_0485 started...
# ---------- KsponSpeech_0486 started...
# ---------- KsponSpeech_0487 started...
# ---------- KsponSpeech_0488 started...
# ---------- KsponSpeech_0489 started...
# ---------- KsponSpeech_0490 started...
# ---------- KsponSpeech_0491 started...
# ---------- KsponSpeech_0492 started...
# ---------- KsponSpeech_0493 started...
# ---------- KsponSpeech_0494 started...
# ---------- KsponSpeech_0495 started...
# ---------- KsponSpeech_0496 started...
# ----- KsponSpeech_05 started...
# ---------- KsponSpeech_0497 started...
# ---------- KsponSpeech_0498 started...
# ---------- KsponSpeech_0499 started...
# ---------- KsponSpeech_0500 started...
# ---------- KsponSpeech_0501 started...
# ---------- KsponSpeech_0502 started...
# ---------- KsponSpeech_0503 started...
# ---------- KsponSpeech_0504 started...
# ---------- KsponSpeech_0505 started...
# ---------- KsponSpeech_0506 started...
# ---------- KsponSpeech_0507 started...
# ---------- KsponSpeech_0508 started...
# ---------- KsponSpeech_0509 started...
# ---------- KsponSpeech_0510 started...
# ---------- KsponSpeech_0511 started...
# ---------- KsponSpeech_0512 started...
# ---------- KsponSpeech_0513 started...
# ---------- KsponSpeech_0514 started...
# ---------- KsponSpeech_0515 started...
# ---------- KsponSpeech_0516 started...
# ---------- KsponSpeech_0517 started...
# ---------- KsponSpeech_0518 started...
# ---------- KsponSpeech_0519 started...
# ---------- KsponSpeech_0520 started...
# ---------- KsponSpeech_0521 started...
# ---------- KsponSpeech_0522 started...
# ---------- KsponSpeech_0523 started...
# ---------- KsponSpeech_0524 started...
# ---------- KsponSpeech_0525 started...
# ---------- KsponSpeech_0526 started...
# ---------- KsponSpeech_0527 started...
# ---------- KsponSpeech_0528 started...
# ---------- KsponSpeech_0529 started...
# ---------- KsponSpeech_0530 started...
# ---------- KsponSpeech_0531 started...
# ---------- KsponSpeech_0532 started...
# ---------- KsponSpeech_0533 started...
# ---------- KsponSpeech_0534 started...
# ---------- KsponSpeech_0535 started...
# ---------- KsponSpeech_0536 started...
# ---------- KsponSpeech_0537 started...
# ---------- KsponSpeech_0538 started...
# ---------- KsponSpeech_0539 started...
# ---------- KsponSpeech_0540 started...
# ---------- KsponSpeech_0541 started...
# ---------- KsponSpeech_0542 started...
# ---------- KsponSpeech_0543 started...
# ---------- KsponSpeech_0544 started...
# ---------- KsponSpeech_0545 started...
# ---------- KsponSpeech_0546 started...
# ---------- KsponSpeech_0547 started...
# ---------- KsponSpeech_0548 started...
# ---------- KsponSpeech_0549 started...
# ---------- KsponSpeech_0550 started...
# ---------- KsponSpeech_0551 started...
# ---------- KsponSpeech_0552 started...
# ---------- KsponSpeech_0553 started...
# ---------- KsponSpeech_0554 started...
# ---------- KsponSpeech_0555 started...
# ---------- KsponSpeech_0556 started...
# ---------- KsponSpeech_0557 started...
# ---------- KsponSpeech_0558 started...
# ---------- KsponSpeech_0559 started...
# ---------- KsponSpeech_0560 started...
# ---------- KsponSpeech_0561 started...
# ---------- KsponSpeech_0562 started...
# ---------- KsponSpeech_0563 started...
# ---------- KsponSpeech_0564 started...
# ---------- KsponSpeech_0565 started...
# ---------- KsponSpeech_0566 started...
# ---------- KsponSpeech_0567 started...
# ---------- KsponSpeech_0568 started...
# ---------- KsponSpeech_0569 started...
# ---------- KsponSpeech_0570 started...
# ---------- KsponSpeech_0571 started...
# ---------- KsponSpeech_0572 started...
# ---------- KsponSpeech_0573 started...
# ---------- KsponSpeech_0574 started...
# ---------- KsponSpeech_0575 started...
# ---------- KsponSpeech_0576 started...
# ---------- KsponSpeech_0577 started...
# ---------- KsponSpeech_0578 started...
# ---------- KsponSpeech_0579 started...
# ---------- KsponSpeech_0580 started...
# ---------- KsponSpeech_0581 started...
# ---------- KsponSpeech_0582 started...
# ---------- KsponSpeech_0583 started...
# ---------- KsponSpeech_0584 started...
# ---------- KsponSpeech_0585 started...
# ---------- KsponSpeech_0586 started...
# ---------- KsponSpeech_0587 started...
# ---------- KsponSpeech_0588 started...
# ---------- KsponSpeech_0589 started...
# ---------- KsponSpeech_0590 started...
# ---------- KsponSpeech_0591 started...
# ---------- KsponSpeech_0592 started...
# ---------- KsponSpeech_0593 started...
# ---------- KsponSpeech_0594 started...
# ---------- KsponSpeech_0595 started...
# ---------- KsponSpeech_0596 started...
# ---------- KsponSpeech_0597 started...
# ---------- KsponSpeech_0598 started...
# ---------- KsponSpeech_0599 started...
# ---------- KsponSpeech_0600 started...
# ---------- KsponSpeech_0601 started...
# ---------- KsponSpeech_0602 started...
# ---------- KsponSpeech_0603 started...
# ---------- KsponSpeech_0604 started...
# ---------- KsponSpeech_0605 started...
# ---------- KsponSpeech_0606 started...
# ---------- KsponSpeech_0607 started...
# ---------- KsponSpeech_0608 started...
# ---------- KsponSpeech_0609 started...
# ---------- KsponSpeech_0610 started...
# ---------- KsponSpeech_0611 started...
# ---------- KsponSpeech_0612 started...
# ---------- KsponSpeech_0613 started...
# ---------- KsponSpeech_0614 started...
# ---------- KsponSpeech_0615 started...
# ---------- KsponSpeech_0616 started...
# ---------- KsponSpeech_0617 started...
# ---------- KsponSpeech_0618 started...
# ---------- KsponSpeech_0619 started...
# ---------- KsponSpeech_0620 started...
# ---------- KsponSpeech_0621 started...
# ---------- KsponSpeech_0622 started...
# ---------- KsponSpeech_0623 started...
#
#
#
# total_fn: 622545
# ----- ⚡Create Target Text Ended !!!

# %% [markdown]
# ## 5. Create data list

# %%
import pandas as pd

df = pd.read_csv(BASE_PATH + 'aihub_labels.csv', encoding='ms949')
start1 = len(df) - len(df[df.freq == 1]) + 1

# total_fn = ??? (위에서 계산)
train_num = int(total_fn * 0.98)
test_num = total_fn - train_num

train_data_list = {'audio': [], 'label': []}
test_data_list = {'audio': [], 'label': []}

aihub_labels = pd.read_csv(BASE_PATH + 'aihub_labels.csv', encoding='ms949')
rare_labels = aihub_labels['char'][start1:]

# %%
import os

audio_paths = []
target_paths = []

'''
temp = os.listdir(BASE_PATH)
# f1_names = [t for t in temp if 'KsponSpeech_0' in t]
f1_names = ['KsponSpeech_01'] ### test
print(f1_names)
'''

for f1 in f1_names:
    print(f'----- {f1} started... ')
    f2_names = os.listdir(BASE_PATH + f1 + '/')
    for f2 in f2_names:
        if 'KsponSpeech_' not in f2:
            continue
        print(f'---------- {f2} started... ')
        f_names = os.listdir(BASE_PATH + f1 + '/' + f2 + '/')
        for fn in f_names:
            if '.pcm' in fn:
                audio_paths.append(f1 + '/' + f2 + '/' + fn)
                target_paths.append(f1 + '/' + f2 + '/KsponSpeech_label_' + fn.split('_')[1][:6] + '.txt')
    
print('\n\n')
print('----- ⚡ Create audio/target path Ended !!!')
# Out:
# 27 started...
# ---------- KsponSpeech_0128 started...
# ---------- KsponSpeech_0129 started...
# ---------- KsponSpeech_0130 started...
# ---------- KsponSpeech_0131 started...
# ---------- KsponSpeech_0132 started...
# ---------- KsponSpeech_0133 started...
# ---------- KsponSpeech_0134 started...
# ---------- KsponSpeech_0135 started...
# ---------- KsponSpeech_0136 started...
# ---------- KsponSpeech_0137 started...
# ---------- KsponSpeech_0138 started...
# ---------- KsponSpeech_0139 started...
# ---------- KsponSpeech_0140 started...
# ---------- KsponSpeech_0141 started...
# ---------- KsponSpeech_0142 started...
# ---------- KsponSpeech_0143 started...
# ---------- KsponSpeech_0144 started...
# ---------- KsponSpeech_0145 started...
# ---------- KsponSpeech_0146 started...
# ---------- KsponSpeech_0147 started...
# ---------- KsponSpeech_0148 started...
# ---------- KsponSpeech_0149 started...
# ---------- KsponSpeech_0150 started...
# ---------- KsponSpeech_0151 started...
# ---------- KsponSpeech_0152 started...
# ---------- KsponSpeech_0153 started...
# ---------- KsponSpeech_0154 started...
# ---------- KsponSpeech_0155 started...
# ---------- KsponSpeech_0156 started...
# ---------- KsponSpeech_0157 started...
# ---------- KsponSpeech_0158 started...
# ---------- KsponSpeech_0159 started...
# ---------- KsponSpeech_0160 started...
# ---------- KsponSpeech_0161 started...
# ---------- KsponSpeech_0162 started...
# ---------- KsponSpeech_0163 started...
# ---------- KsponSpeech_0164 started...
# ---------- KsponSpeech_0165 started...
# ---------- KsponSpeech_0166 started...
# ---------- KsponSpeech_0167 started...
# ---------- KsponSpeech_0168 started...
# ---------- KsponSpeech_0169 started...
# ---------- KsponSpeech_0170 started...
# ---------- KsponSpeech_0171 started...
# ---------- KsponSpeech_0172 started...
# ---------- KsponSpeech_0173 started...
# ---------- KsponSpeech_0174 started...
# ---------- KsponSpeech_0175 started...
# ---------- KsponSpeech_0176 started...
# ---------- KsponSpeech_0177 started...
# ---------- KsponSpeech_0178 started...
# ---------- KsponSpeech_0179 started...
# ---------- KsponSpeech_0180 started...
# ---------- KsponSpeech_0181 started...
# ---------- KsponSpeech_0182 started...
# ---------- KsponSpeech_0183 started...
# ---------- KsponSpeech_0184 started...
# ---------- KsponSpeech_0185 started...
# ---------- KsponSpeech_0186 started...
# ---------- KsponSpeech_0187 started...
# ---------- KsponSpeech_0188 started...
# ---------- KsponSpeech_0189 started...
# ---------- KsponSpeech_0190 started...
# ---------- KsponSpeech_0191 started...
# ---------- KsponSpeech_0192 started...
# ---------- KsponSpeech_0193 started...
# ---------- KsponSpeech_0194 started...
# ---------- KsponSpeech_0195 started...
# ---------- KsponSpeech_0196 started...
# ---------- KsponSpeech_0197 started...
# ---------- KsponSpeech_0198 started...
# ---------- KsponSpeech_0199 started...
# ---------- KsponSpeech_0200 started...
# ---------- KsponSpeech_0201 started...
# ---------- KsponSpeech_0202 started...
# ---------- KsponSpeech_0203 started...
# ---------- KsponSpeech_0204 started...
# ---------- KsponSpeech_0205 started...
# ---------- KsponSpeech_0206 started...
# ---------- KsponSpeech_0207 started...
# ---------- KsponSpeech_0208 started...
# ---------- KsponSpeech_0209 started...
# ---------- KsponSpeech_0210 started...
# ---------- KsponSpeech_0211 started...
# ---------- KsponSpeech_0212 started...
# ---------- KsponSpeech_0213 started...
# ---------- KsponSpeech_0214 started...
# ---------- KsponSpeech_0215 started...
# ---------- KsponSpeech_0216 started...
# ---------- KsponSpeech_0217 started...
# ---------- KsponSpeech_0218 started...
# ---------- KsponSpeech_0219 started...
# ---------- KsponSpeech_0220 started...
# ---------- KsponSpeech_0221 started...
# ---------- KsponSpeech_0222 started...
# ---------- KsponSpeech_0223 started...
# ---------- KsponSpeech_0224 started...
# ---------- KsponSpeech_0225 started...
# ---------- KsponSpeech_0226 started...
# ---------- KsponSpeech_0227 started...
# ---------- KsponSpeech_0228 started...
# ---------- KsponSpeech_0229 started...
# ---------- KsponSpeech_0230 started...
# ---------- KsponSpeech_0231 started...
# ---------- KsponSpeech_0232 started...
# ---------- KsponSpeech_0233 started...
# ---------- KsponSpeech_0234 started...
# ---------- KsponSpeech_0235 started...
# ---------- KsponSpeech_0236 started...
# ---------- KsponSpeech_0237 started...
# ---------- KsponSpeech_0238 started...
# ---------- KsponSpeech_0239 started...
# ---------- KsponSpeech_0240 started...
# ---------- KsponSpeech_0241 started...
# ---------- KsponSpeech_0242 started...
# ---------- KsponSpeech_0243 started...
# ---------- KsponSpeech_0244 started...
# ---------- KsponSpeech_0245 started...
# ---------- KsponSpeech_0246 started...
# ---------- KsponSpeech_0247 started...
# ---------- KsponSpeech_0248 started...
# ----- KsponSpeech_03 started...
# ---------- KsponSpeech_0249 started...
# ---------- KsponSpeech_0250 started...
# ---------- KsponSpeech_0251 started...
# ---------- KsponSpeech_0252 started...
# ---------- KsponSpeech_0253 started...
# ---------- KsponSpeech_0254 started...
# ---------- KsponSpeech_0255 started...
# ---------- KsponSpeech_0256 started...
# ---------- KsponSpeech_0257 started...
# ---------- KsponSpeech_0258 started...
# ---------- KsponSpeech_0259 started...
# ---------- KsponSpeech_0260 started...
# ---------- KsponSpeech_0261 started...
# ---------- KsponSpeech_0262 started...
# ---------- KsponSpeech_0263 started...
# ---------- KsponSpeech_0264 started...
# ---------- KsponSpeech_0265 started...
# ---------- KsponSpeech_0266 started...
# ---------- KsponSpeech_0267 started...
# ---------- KsponSpeech_0268 started...
# ---------- KsponSpeech_0269 started...
# ---------- KsponSpeech_0270 started...
# ---------- KsponSpeech_0271 started...
# ---------- KsponSpeech_0272 started...
# ---------- KsponSpeech_0273 started...
# ---------- KsponSpeech_0274 started...
# ---------- KsponSpeech_0275 started...
# ---------- KsponSpeech_0276 started...
# ---------- KsponSpeech_0277 started...
# ---------- KsponSpeech_0278 started...
# ---------- KsponSpeech_0279 started...
# ---------- KsponSpeech_0280 started...
# ---------- KsponSpeech_0281 started...
# ---------- KsponSpeech_0282 started...
# ---------- KsponSpeech_0283 started...
# ---------- KsponSpeech_0284 started...
# ---------- KsponSpeech_0285 started...
# ---------- KsponSpeech_0286 started...
# ---------- KsponSpeech_0287 started...
# ---------- KsponSpeech_0288 started...
# ---------- KsponSpeech_0289 started...
# ---------- KsponSpeech_0290 started...
# ---------- KsponSpeech_0291 started...
# ---------- KsponSpeech_0292 started...
# ---------- KsponSpeech_0293 started...
# ---------- KsponSpeech_0294 started...
# ---------- KsponSpeech_0295 started...
# ---------- KsponSpeech_0296 started...
# ---------- KsponSpeech_0297 started...
# ---------- KsponSpeech_0298 started...
# ---------- KsponSpeech_0299 started...
# ---------- KsponSpeech_0300 started...
# ---------- KsponSpeech_0301 started...
# ---------- KsponSpeech_0302 started...
# ---------- KsponSpeech_0303 started...
# ---------- KsponSpeech_0304 started...
# ---------- KsponSpeech_0305 started...
# ---------- KsponSpeech_0306 started...
# ---------- KsponSpeech_0307 started...
# ---------- KsponSpeech_0308 started...
# ---------- KsponSpeech_0309 started...
# ---------- KsponSpeech_0310 started...
# ---------- KsponSpeech_0311 started...
# ---------- KsponSpeech_0312 started...
# ---------- KsponSpeech_0313 started...
# ---------- KsponSpeech_0314 started...
# ---------- KsponSpeech_0315 started...
# ---------- KsponSpeech_0316 started...
# ---------- KsponSpeech_0317 started...
# ---------- KsponSpeech_0318 started...
# ---------- KsponSpeech_0319 started...
# ---------- KsponSpeech_0320 started...
# ---------- KsponSpeech_0321 started...
# ---------- KsponSpeech_0322 started...
# ---------- KsponSpeech_0323 started...
# ---------- KsponSpeech_0324 started...
# ---------- KsponSpeech_0325 started...
# ---------- KsponSpeech_0326 started...
# ---------- KsponSpeech_0327 started...
# ---------- KsponSpeech_0328 started...
# ---------- KsponSpeech_0329 started...
# ---------- KsponSpeech_0330 started...
# ---------- KsponSpeech_0331 started...
# ---------- KsponSpeech_0332 started...
# ---------- KsponSpeech_0333 started...
# ---------- KsponSpeech_0334 started...
# ---------- KsponSpeech_0335 started...
# ---------- KsponSpeech_0336 started...
# ---------- KsponSpeech_0337 started...
# ---------- KsponSpeech_0338 started...
# ---------- KsponSpeech_0339 started...
# ---------- KsponSpeech_0340 started...
# ---------- KsponSpeech_0341 started...
# ---------- KsponSpeech_0342 started...
# ---------- KsponSpeech_0343 started...
# ---------- KsponSpeech_0344 started...
# ---------- KsponSpeech_0345 started...
# ---------- KsponSpeech_0346 started...
# ---------- KsponSpeech_0347 started...
# ---------- KsponSpeech_0348 started...
# ---------- KsponSpeech_0349 started...
# ---------- KsponSpeech_0350 started...
# ---------- KsponSpeech_0351 started...
# ---------- KsponSpeech_0352 started...
# ---------- KsponSpeech_0353 started...
# ---------- KsponSpeech_0354 started...
# ---------- KsponSpeech_0355 started...
# ---------- KsponSpeech_0356 started...
# ---------- KsponSpeech_0357 started...
# ---------- KsponSpeech_0358 started...
# ---------- KsponSpeech_0359 started...
# ---------- KsponSpeech_0360 started...
# ---------- KsponSpeech_0361 started...
# ---------- KsponSpeech_0362 started...
# ---------- KsponSpeech_0363 started...
# ---------- KsponSpeech_0364 started...
# ---------- KsponSpeech_0365 started...
# ---------- KsponSpeech_0366 started...
# ---------- KsponSpeech_0367 started...
# ---------- KsponSpeech_0368 started...
# ---------- KsponSpeech_0369 started...
# ---------- KsponSpeech_0370 started...
# ---------- KsponSpeech_0371 started...
# ---------- KsponSpeech_0372 started...
# ----- KsponSpeech_04 started...
# ---------- KsponSpeech_0373 started...
# ---------- KsponSpeech_0374 started...
# ---------- KsponSpeech_0375 started...
# ---------- KsponSpeech_0376 started...
# ---------- KsponSpeech_0377 started...
# ---------- KsponSpeech_0378 started...
# ---------- KsponSpeech_0379 started...
# ---------- KsponSpeech_0380 started...
# ---------- KsponSpeech_0381 started...
# ---------- KsponSpeech_0382 started...
# ---------- KsponSpeech_0383 started...
# ---------- KsponSpeech_0384 started...
# ---------- KsponSpeech_0385 started...
# ---------- KsponSpeech_0386 started...
# ---------- KsponSpeech_0387 started...
# ---------- KsponSpeech_0388 started...
# ---------- KsponSpeech_0389 started...
# ---------- KsponSpeech_0390 started...
# ---------- KsponSpeech_0391 started...
# ---------- KsponSpeech_0392 started...
# ---------- KsponSpeech_0393 started...
# ---------- KsponSpeech_0394 started...
# ---------- KsponSpeech_0395 started...
# ---------- KsponSpeech_0396 started...
# ---------- KsponSpeech_0397 started...
# ---------- KsponSpeech_0398 started...
# ---------- KsponSpeech_0399 started...
# ---------- KsponSpeech_0400 started...
# ---------- KsponSpeech_0401 started...
# ---------- KsponSpeech_0402 started...
# ---------- KsponSpeech_0403 started...
# ---------- KsponSpeech_0404 started...
# ---------- KsponSpeech_0405 started...
# ---------- KsponSpeech_0406 started...
# ---------- KsponSpeech_0407 started...
# ---------- KsponSpeech_0408 started...
# ---------- KsponSpeech_0409 started...
# ---------- KsponSpeech_0410 started...
# ---------- KsponSpeech_0411 started...
# ---------- KsponSpeech_0412 started...
# ---------- KsponSpeech_0413 started...
# ---------- KsponSpeech_0414 started...
# ---------- KsponSpeech_0415 started...
# ---------- KsponSpeech_0416 started...
# ---------- KsponSpeech_0417 started...
# ---------- KsponSpeech_0418 started...
# ---------- KsponSpeech_0419 started...
# ---------- KsponSpeech_0420 started...
# ---------- KsponSpeech_0421 started...
# ---------- KsponSpeech_0422 started...
# ---------- KsponSpeech_0423 started...
# ---------- KsponSpeech_0424 started...
# ---------- KsponSpeech_0425 started...
# ---------- KsponSpeech_0426 started...
# ---------- KsponSpeech_0427 started...
# ---------- KsponSpeech_0428 started...
# ---------- KsponSpeech_0429 started...
# ---------- KsponSpeech_0430 started...
# ---------- KsponSpeech_0431 started...
# ---------- KsponSpeech_0432 started...
# ---------- KsponSpeech_0433 started...
# ---------- KsponSpeech_0434 started...
# ---------- KsponSpeech_0435 started...
# ---------- KsponSpeech_0436 started...
# ---------- KsponSpeech_0437 started...
# ---------- KsponSpeech_0438 started...
# ---------- KsponSpeech_0439 started...
# ---------- KsponSpeech_0440 started...
# ---------- KsponSpeech_0441 started...
# ---------- KsponSpeech_0442 started...
# ---------- KsponSpeech_0443 started...
# ---------- KsponSpeech_0444 started...
# ---------- KsponSpeech_0445 started...
# ---------- KsponSpeech_0446 started...
# ---------- KsponSpeech_0447 started...
# ---------- KsponSpeech_0448 started...
# ---------- KsponSpeech_0449 started...
# ---------- KsponSpeech_0450 started...
# ---------- KsponSpeech_0451 started...
# ---------- KsponSpeech_0452 started...
# ---------- KsponSpeech_0453 started...
# ---------- KsponSpeech_0454 started...
# ---------- KsponSpeech_0455 started...
# ---------- KsponSpeech_0456 started...
# ---------- KsponSpeech_0457 started...
# ---------- KsponSpeech_0458 started...
# ---------- KsponSpeech_0459 started...
# ---------- KsponSpeech_0460 started...
# ---------- KsponSpeech_0461 started...
# ---------- KsponSpeech_0462 started...
# ---------- KsponSpeech_0463 started...
# ---------- KsponSpeech_0464 started...
# ---------- KsponSpeech_0465 started...
# ---------- KsponSpeech_0466 started...
# ---------- KsponSpeech_0467 started...
# ---------- KsponSpeech_0468 started...
# ---------- KsponSpeech_0469 started...
# ---------- KsponSpeech_0470 started...
# ---------- KsponSpeech_0471 started...
# ---------- KsponSpeech_0472 started...
# ---------- KsponSpeech_0473 started...
# ---------- KsponSpeech_0474 started...
# ---------- KsponSpeech_0475 started...
# ---------- KsponSpeech_0476 started...
# ---------- KsponSpeech_0477 started...
# ---------- KsponSpeech_0478 started...
# ---------- KsponSpeech_0479 started...
# ---------- KsponSpeech_0480 started...
# ---------- KsponSpeech_0481 started...
# ---------- KsponSpeech_0482 started...
# ---------- KsponSpeech_0483 started...
# ---------- KsponSpeech_0484 started...
# ---------- KsponSpeech_0485 started...
# ---------- KsponSpeech_0486 started...
# ---------- KsponSpeech_0487 started...
# ---------- KsponSpeech_0488 started...
# ---------- KsponSpeech_0489 started...
# ---------- KsponSpeech_0490 started...
# ---------- KsponSpeech_0491 started...
# ---------- KsponSpeech_0492 started...
# ---------- KsponSpeech_0493 started...
# ---------- KsponSpeech_0494 started...
# ---------- KsponSpeech_0495 started...
# ---------- KsponSpeech_0496 started...
# ----- KsponSpeech_05 started...
# ---------- KsponSpeech_0497 started...
# ---------- KsponSpeech_0498 started...
# ---------- KsponSpeech_0499 started...
# ---------- KsponSpeech_0500 started...
# ---------- KsponSpeech_0501 started...
# ---------- KsponSpeech_0502 started...
# ---------- KsponSpeech_0503 started...
# ---------- KsponSpeech_0504 started...
# ---------- KsponSpeech_0505 started...
# ---------- KsponSpeech_0506 started...
# ---------- KsponSpeech_0507 started...
# ---------- KsponSpeech_0508 started...
# ---------- KsponSpeech_0509 started...
# ---------- KsponSpeech_0510 started...
# ---------- KsponSpeech_0511 started...
# ---------- KsponSpeech_0512 started...
# ---------- KsponSpeech_0513 started...
# ---------- KsponSpeech_0514 started...
# ---------- KsponSpeech_0515 started...
# ---------- KsponSpeech_0516 started...
# ---------- KsponSpeech_0517 started...
# ---------- KsponSpeech_0518 started...
# ---------- KsponSpeech_0519 started...
# ---------- KsponSpeech_0520 started...
# ---------- KsponSpeech_0521 started...
# ---------- KsponSpeech_0522 started...
# ---------- KsponSpeech_0523 started...
# ---------- KsponSpeech_0524 started...
# ---------- KsponSpeech_0525 started...
# ---------- KsponSpeech_0526 started...
# ---------- KsponSpeech_0527 started...
# ---------- KsponSpeech_0528 started...
# ---------- KsponSpeech_0529 started...
# ---------- KsponSpeech_0530 started...
# ---------- KsponSpeech_0531 started...
# ---------- KsponSpeech_0532 started...
# ---------- KsponSpeech_0533 started...
# ---------- KsponSpeech_0534 started...
# ---------- KsponSpeech_0535 started...
# ---------- KsponSpeech_0536 started...
# ---------- KsponSpeech_0537 started...
# ---------- KsponSpeech_0538 started...
# ---------- KsponSpeech_0539 started...
# ---------- KsponSpeech_0540 started...
# ---------- KsponSpeech_0541 started...
# ---------- KsponSpeech_0542 started...
# ---------- KsponSpeech_0543 started...
# ---------- KsponSpeech_0544 started...
# ---------- KsponSpeech_0545 started...
# ---------- KsponSpeech_0546 started...
# ---------- KsponSpeech_0547 started...
# ---------- KsponSpeech_0548 started...
# ---------- KsponSpeech_0549 started...
# ---------- KsponSpeech_0550 started...
# ---------- KsponSpeech_0551 started...
# ---------- KsponSpeech_0552 started...
# ---------- KsponSpeech_0553 started...
# ---------- KsponSpeech_0554 started...
# ---------- KsponSpeech_0555 started...
# ---------- KsponSpeech_0556 started...
# ---------- KsponSpeech_0557 started...
# ---------- KsponSpeech_0558 started...
# ---------- KsponSpeech_0559 started...
# ---------- KsponSpeech_0560 started...
# ---------- KsponSpeech_0561 started...
# ---------- KsponSpeech_0562 started...
# ---------- KsponSpeech_0563 started...
# ---------- KsponSpeech_0564 started...
# ---------- KsponSpeech_0565 started...
# ---------- KsponSpeech_0566 started...
# ---------- KsponSpeech_0567 started...
# ---------- KsponSpeech_0568 started...
# ---------- KsponSpeech_0569 started...
# ---------- KsponSpeech_0570 started...
# ---------- KsponSpeech_0571 started...
# ---------- KsponSpeech_0572 started...
# ---------- KsponSpeech_0573 started...
# ---------- KsponSpeech_0574 started...
# ---------- KsponSpeech_0575 started...
# ---------- KsponSpeech_0576 started...
# ---------- KsponSpeech_0577 started...
# ---------- KsponSpeech_0578 started...
# ---------- KsponSpeech_0579 started...
# ---------- KsponSpeech_0580 started...
# ---------- KsponSpeech_0581 started...
# ---------- KsponSpeech_0582 started...
# ---------- KsponSpeech_0583 started...
# ---------- KsponSpeech_0584 started...
# ---------- KsponSpeech_0585 started...
# ---------- KsponSpeech_0586 started...
# ---------- KsponSpeech_0587 started...
# ---------- KsponSpeech_0588 started...
# ---------- KsponSpeech_0589 started...
# ---------- KsponSpeech_0590 started...
# ---------- KsponSpeech_0591 started...
# ---------- KsponSpeech_0592 started...
# ---------- KsponSpeech_0593 started...
# ---------- KsponSpeech_0594 started...
# ---------- KsponSpeech_0595 started...
# ---------- KsponSpeech_0596 started...
# ---------- KsponSpeech_0597 started...
# ---------- KsponSpeech_0598 started...
# ---------- KsponSpeech_0599 started...
# ---------- KsponSpeech_0600 started...
# ---------- KsponSpeech_0601 started...
# ---------- KsponSpeech_0602 started...
# ---------- KsponSpeech_0603 started...
# ---------- KsponSpeech_0604 started...
# ---------- KsponSpeech_0605 started...
# ---------- KsponSpeech_0606 started...
# ---------- KsponSpeech_0607 started...
# ---------- KsponSpeech_0608 started...
# ---------- KsponSpeech_0609 started...
# ---------- KsponSpeech_0610 started...
# ---------- KsponSpeech_0611 started...
# ---------- KsponSpeech_0612 started...
# ---------- KsponSpeech_0613 started...
# ---------- KsponSpeech_0614 started...
# ---------- KsponSpeech_0615 started...
# ---------- KsponSpeech_0616 started...
# ---------- KsponSpeech_0617 started...
# ---------- KsponSpeech_0618 started...
# ---------- KsponSpeech_0619 started...
# ---------- KsponSpeech_0620 started...
# ---------- KsponSpeech_0621 started...
# ---------- KsponSpeech_0622 started...
# ---------- KsponSpeech_0623 started...
#
#
#
# ----- ⚡ Create audio/target path Ended !!!

# %%
import random

data_paths = list(zip(audio_paths, target_paths))
random.shuffle(data_paths)
audio_paths, target_paths = zip(*data_paths)

# %%
from tqdm import trange

# BASE_PATH = '/content/drive/My Drive/googledrive/'
train_full = False
train_dict = {'audio': [], 'label': []}
test_dict = {'audio': [], 'label': []}

for idx in trange(len(audio_paths)):
    audio = audio_paths[idx]
    target = target_paths[idx]
    if len(train_dict['audio']) == train_num:
        train_full = True
    if train_full:
        test_dict['audio'].append(audio)
        test_dict['label'].append(target)
    else:
        rare_in = False
        sentence = None
        with open(BASE_PATH + audio.split('.')[0]+'.txt', encoding='ms949') as f:
            sentence = f.readline()
            
        for rare in rare_labels:
            if rare in sentence:
                rare_in = True
                break
        if rare_in:
            test_dict['audio'].append(audio)
            test_dict['label'].append(target)
        else:
            train_dict['audio'].append(audio)
            train_dict['label'].append(target)
            
print('\n\n')
print('----- ⚡ Create train/test dict Ended !!!')
# Out:
# 100%|██████████| 622545/622545 [08:38<00:00, 1200.99it/s]
#
#
# ----- ⚡ Create train/test dict Ended !!!

# %%
test_df = pd.DataFrame(test_dict)
train_df = pd.DataFrame(train_dict)

test_df.to_csv(BASE_PATH + 'test_list.csv', encoding='ms949', index=False)
train_df.to_csv(BASE_PATH + 'train_list.csv', encoding='ms949', index=False)

# %%
print('\n\n')
print('----- 👍👍👍 All Preprocess Ended !!!')
# Out:
# ----- 👍👍👍 All Preprocess Ended !!!
