# %% [markdown]
# ### 더미변수 (dummy variable)와 상호작용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# #### 1. Read in the data:

# %%
df = pd.read_csv('data_studentlist_en.csv', header='infer',encoding='latin1')

# %%
# We will use 3 variables: height, weight and gender.
df.head(5)
# Out:
#               name gender  age  grade absence bloodtype  height  weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %% [markdown]
# ####  2. Linear regression without dummy variable:
# <br>
# The formula is: weight ~ height

# %%
# Do the regression as usual.
lm = LinearRegression()
X = df.height.values.reshape(-1,1)
Y = df.weight.values.reshape(-1,1)
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
rsq1 = lm.score(X,Y)
rmse1 = np.sqrt(metrics.mean_squared_error(Y, lm.predict(X)))

# %%
# Visualize.
# No need to distinguish the regression line by gender.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='black')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# ####  3. Linear regression with dummy variable:
# <br>
# The formula is: weight ~ height + gender

# %%
# Create a dummy variable for 'gender':
gender_dummy = pd.get_dummies(df.gender, drop_first=True, prefix='gender')
X = df[['height']].join(gender_dummy)
Y = df[['weight']]

# %%
# Do the regression as usual.
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
b2 = lm.coef_[0][1]
rsq2 = lm.score(X,Y)
rmse2 = np.sqrt(metrics.mean_squared_error(Y, lm.predict(X)))

# %%
# Visualize.
# Distinguish the regression lines by gender.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='red')
plt.plot(x_grid, (b0 + b2) + b1*x_grid, linestyle='--',linewidth=1,color='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# ####  4. Linear regression with dummy variable that interacts:
# <br>
# The formula is: weight ~ height + gender + height $\times$ gender

# %%
# Create a dummy variable for 'gender':
gender_dummy = pd.get_dummies(df.gender, drop_first=True, prefix='gender')
X = df[['height']].join(gender_dummy)
Y = df[['weight']]

# %%
# Create the interaction term. 
X['height x gender_M'] = X['height']*X['gender_M']
X.head(5)
# Out:
#    height  gender_M  height x gender_M
# 0   165.3         1              165.3
# 1   170.1         0                0.0
# 2   175.0         1              175.0
# 3   182.1         1              182.1
# 4   168.0         0                0.0

# %%
# Do the regression as usual.
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
b2 = lm.coef_[0][1]
b3 = lm.coef_[0][2]
rsq3 = lm.score(X,Y)
rmse3 = np.sqrt(metrics.mean_squared_error(Y, lm.predict(X)))

# %%
# Visualize.
# Distinguish the regression lines by gender.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='red')
plt.plot(x_grid, (b0 + b2) + (b1+b3)*x_grid, linestyle='--',linewidth=1,color='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# #### 5. Compare  $R^2$, RMSE for the different cases:

# %%
np.round([rsq1, rsq2, rsq3],3)
# Out:
# array([0.441, 0.762, 0.787])

# %%
np.round([rmse1, rmse2, rmse3],3)
# Out:
# array([8.595, 5.613, 5.307])

# %% [markdown]
# NOTE: With a dummy variable that interacts, the $R^2$ is the highest and the *RMSE* is the lowest.
